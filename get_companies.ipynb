# %%
import pandas as pd
import wikipedia as wp


url = wp.page("List of S&P 500 companies").html().encode("UTF-8")
table = pd.read_html(url)[0]

# %%
companies = table[["Symbol", "Security"]]

# %%
companies.to_csv("companies.csv")
